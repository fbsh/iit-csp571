# %% [markdown]
# # 2

# %% [markdown]
# # a

# %% [markdown]
# In this case $\hat{g}=0$ because a large smoothing parameter forces $g^{(0)}(x) \rightarrow 0$.

# %% [markdown]
# # b

# %% [markdown]
# In this case $\hat{g}=c$ because a large smoothing parameter forces $g^{(1)}(x) \rightarrow 0$.

# %% [markdown]
# # c

# %% [markdown]
# In this case $\hat{g}=c x+d$ because a large smoothing parameter forces $g^{(2)}(x) \rightarrow 0$

# %% [markdown]
# # d

# %% [markdown]
# In this case $\hat{g}=c x^{2}+d x+e$ because a large smoothing parameter forces $g^{(3)}(x) \rightarrow 0$

# %% [markdown]
# # e

# %% [markdown]
# The penalty term doesn't play any role, so in this case $g$ is the interpolating spline.

# %% [markdown]
# # 3

# %%
x = -2:2
y = 1 + x + -2 * (x-1)^2 * I(x>1)
plot(x, y)
# Out:
# plot without title

# %% [markdown]
# The curve is linear between $-2$ and $1: y=1+x$ and quadratic between 1 , and $2: y=1+x-2(x-1)^{2}$.

# %% [markdown]
# # 4

# %%
x = -2:2
y = c(1 + 0 + 0, # x = -2
      1 + 0 + 0, # x = -1
      1 + 1 + 0, # x = 0
      1 + (1-0) + 0, # x = 1
      1 + (1-1) + 0 # x =2
      )
plot(x,y)
# Out:
# plot without title

# %% [markdown]
# The curve is constant between $-2$ and $0: y=1$, constant between 0 and $1: y=2$, and linear between 1 and 2 $: y=3-x \text {. }$

# %% [markdown]
# # 5

# %% [markdown]
# # a

# %% [markdown]
# The smoothing spline $\hat{g}_{2}$ will probably have the smaller training RSS because it will be a higher order polynomial due to the order of the penalty term.

# %% [markdown]
# # b

# %% [markdown]
# As mentioned above we expect $\hat{g}_{2}$ to be more flexible, so it may overfit the data. It will probably be $\hat{g}_{1}$ that have the smaller test RSS.

# %% [markdown]
# # c

# %% [markdown]
# If $\lambda=0$, we have $\hat{g}_{1}=\hat{g}_{2}$, so they will have the same training and test $R S S$.
